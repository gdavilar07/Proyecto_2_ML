# %% [markdown]
# # Notebook 2: Análisis Exploratorio de Datos (EDA)
#
# Este notebook realiza un análisis exploratorio de los datos para entender mejor las características y distribuciones.
# Vamos a explorar las distribuciones, correlaciones y detectar valores atípicos.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el dataset
file_path = '../data/raw/HeartDiseaseTrain-Test.csv'
data = pd.read_csv(file_path)

# Distribución de las variables numéricas
data.hist(figsize=(10, 10))
plt.show()

# Correlación entre variables
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()

# Gráficos de cajas para detectar outliers
for column in ['age', 'resting_blood_pressure', 'cholestoral', 'oldpeak']:
    plt.figure()
    sns.boxplot(data[column])
    plt.title(f'Distribución de {column}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 15
#      13 # Correlación entre variables
#      14 plt.figure(figsize=(12, 10))
# ---> 15 sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
#      16 plt.show()
#      18 # Gráficos de cajas para detectar outliers
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...
